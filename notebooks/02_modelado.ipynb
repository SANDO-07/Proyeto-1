# %% [markdown]
# # Notebook 02 - Modelado base
# Entrenamiento del Random Forest

# %%
import pandas as pd
import pickle
from pathlib import Path
ROOT = Path.cwd().resolve().parents[0] if (Path.cwd()/ 'data').exists() else Path.cwd()
metrics = __import__('json').loads((ROOT / 'models' / 'metrics.json').read_text(encoding='utf-8'))
metrics

# %%
forecast = pd.read_csv(ROOT / 'data' / 'outputs' / 'calendario_incendios_2026.csv')
forecast.head()
